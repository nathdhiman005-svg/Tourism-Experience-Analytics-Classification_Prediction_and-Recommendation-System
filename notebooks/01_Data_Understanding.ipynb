# %% [markdown]
# # Data Understanding & Profiling
#
# This notebook focuses on profiling the merged dataset to understand data types, missing value distributions, summary statistics, and cardinalities of categorical features.

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
# Load the merged dataset
df = pd.read_csv('../processed_data/raw_merged.csv')
df.head()
# Out:
#    TransactionId  UserId  VisitYear  VisitMonth  VisitMode_id  AttractionId  \
# 0              3   70456       2022          10             2           640
# 1              8    7567       2022          10             4           640
# 2              9   79069       2022          10             3           640
# 3             10   31019       2022          10             3           640
# 4             15   43611       2022          10             2           640
#
#    Rating  VisitModeId VisitModeName  ContinentId  ...  UserContinent  \
# 0       5            2       Couples            5  ...         Europe
# 1       5            4       Friends            2  ...        America
# 2       5            3        Family            2  ...        America
# 3       3            3        Family            5  ...         Europe
# 4       3            2       Couples            5  ...         Europe
#
#          UserRegion     UserCountry    UserCity AttractionCityId  \
# ...

# %% [markdown]
# ## 1. Data Types and Basic Information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52930 entries, 0 to 52929
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TransactionId      52930 non-null  int64
#  1   UserId             52930 non-null  int64
#  2   VisitYear          52930 non-null  int64
#  3   VisitMonth         52930 non-null  int64
#  4   VisitMode_id       52930 non-null  int64
#  5   AttractionId       52930 non-null  int64
#  6   Rating             52930 non-null  int64
#  7   VisitModeId        52930 non-null  int64
#  8   VisitModeName      52930 non-null  str
#  9   ContinentId        52930 non-null  int64
#  10  RegionId           52930 non-null  int64
#  11  CountryId          52930 non-null  int64
#  12  CityId             52922 non-null  float64
#  13  UserContinent      52930 non-null  str
#  14  UserRegion         52930 non-null  str
#  15  UserCountry        52930 non-null  str
# ...

# %% [markdown]
# ## 2. Summary Statistics

# %%
df.describe(include='all')
# Out:
#         TransactionId        UserId     VisitYear    VisitMonth  VisitMode_id  \
# count    52930.000000  52930.000000  52930.000000  52930.000000  52930.000000
# unique            NaN           NaN           NaN           NaN           NaN
# top               NaN           NaN           NaN           NaN           NaN
# freq              NaN           NaN           NaN           NaN           NaN
# mean     70415.130474  45024.522596   2016.351899      6.633100      2.945759
# std      66299.514206  25073.062199      1.732926      3.392979      1.000683
# min          3.000000     14.000000   2013.000000      1.000000      1.000000
# 25%      19646.250000  23470.000000   2015.000000      4.000000      2.000000
# 50%      42770.500000  45533.500000   2016.000000      7.000000      3.000000
# 75%     105638.750000  66667.000000   2018.000000      9.000000      4.000000
# max     211241.000000  88190.000000   2022.000000     12.000000      5.000000
#
# ...

# %% [markdown]
# ## 3. Missing Value Distributions

# %%
# Calculate percentage of missing values per column
missing_percent = (df.isnull().sum() / len(df)) * 100
missing_percent[missing_percent > 0].sort_values(ascending=False)
# Out:
# CityId      0.015114
# UserCity    0.015114
# dtype: float64

# %% [markdown]
# ## 4. Cardinality of Categorical Features

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
df[categorical_cols].nunique().sort_values(ascending=False)
# Out:
# UserCity             5545
# UserCountry           153
# Attraction             30
# AttractionAddress      25
# UserRegion             22
# AttractionType         17
# VisitModeName           5
# UserContinent           5
# AttractionCity          3
# dtype: int64

# %% [markdown]
# ## 5. Target Variable Distributions

# %%
# Ratings distribution (Regression Target)
df['Rating'].value_counts(dropna=False).sort_index()
# Out:
# Rating
# 1     1263
# 2     2035
# 3     7730
# 4    17966
# 5    23936
# Name: count, dtype: int64

# %%
# Visit Mode distribution (Classification Target)
df['VisitModeName'].value_counts(dropna=False)
# Out:
# VisitModeName
# Couples     21620
# Family      15217
# Friends     10945
# Solo         4525
# Business      623
# Name: count, dtype: int64
